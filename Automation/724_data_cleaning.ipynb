# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
import dateutil.parser as parser
from datetime import timedelta
from datetime import date

# %%
import datetime

# %%
writer = pd.ExcelWriter('V:/CC 265420_CS SO/automation/724/output.xlsx', engine='xlsxwriter')

# %%
raw = pd.read_excel('V:/CC 265420_CS SO/automation/724/RAW.xlsx')

# %%
raw
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 0     2023-01-01 07:56:39 ( 21472 )    call  01040262680  728-103708
# 1     2023-01-01 07:40:03 ( 21471 )    call  01062178238  728-100269
# 2     2023-01-01 07:20:00 ( 21470 )    call  01062178238  728-100269
# 3     2023-01-01 07:15:00 ( 21469 )    call  01032125690  728-100723
# 4     2023-01-01 07:13:23 ( 21468 )    call  01050471395  728-100440
# ...                             ...     ...          ...         ...
# 1811  2022-10-01 10:02:23 ( 19846 )    call  01072808195  728-100488
# 1812  2022-10-01 09:18:13 ( 19845 )    call  01049089797  728-108194
# 1813  2022-10-01 09:06:05 ( 19844 )    call  01029226264  728-103207
# 1814  2022-10-01 08:47:10 ( 19843 )      LN  01085213847  728-103378
# 1815  2022-10-01 08:44:30 ( 19842 )    call  01042282772  728-100842
#
#      System ID 사업부  제품별                                   병원명  \
# 0     07020303  DI   CT      Yonsei U. Gangnam Severance Hosp
# ...

# %%
raw.loc[raw['Dispatched/SVA'] == '이관']
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 7     2023-01-01 05:18:58 ( 21465 )    call  01085837171  728-100989
# 32    2022-12-31 07:51:56 ( 21441 )    call  01037176779  728-100426
# 40    2022-12-30 20:00:32 ( 21434 )    call  01088933956  728-100844
# 42    2022-12-30 18:42:39 ( 21433 )    call  01026382393  728-108905
# 46    2022-12-30 07:01:57 ( 21430 )    call  01091359907  728-100932
# ...                             ...     ...          ...         ...
# 1779  2022-10-02 13:44:37 ( 19873 )    call  01082815122         NaN
# 1797  2022-10-01 19:44:50 ( 19856 )    call  01073510811         NaN
# 1799  2022-10-01 19:12:30 ( 19855 )    call  01066455497  728-107727
# 1801  2022-10-01 16:06:47 ( 19854 )    call  01052690928  728-100740
# 1807  2022-10-01 10:27:40 ( 19849 )    call  01084659889  728-100300
#
#      System ID  사업부  제품별                             병원명  \
# 7     10422316   DX  CAI  INJE Univ. Haeundae Paik Hosp.
# ...

# %%
raw = raw.loc[raw['Dispatched/SVA'] != '이관']

# %%
raw
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 0     2023-01-01 07:56:39 ( 21472 )    call  01040262680  728-103708
# 1     2023-01-01 07:40:03 ( 21471 )    call  01062178238  728-100269
# 2     2023-01-01 07:20:00 ( 21470 )    call  01062178238  728-100269
# 3     2023-01-01 07:15:00 ( 21469 )    call  01032125690  728-100723
# 4     2023-01-01 07:13:23 ( 21468 )    call  01050471395  728-100440
# ...                             ...     ...          ...         ...
# 1811  2022-10-01 10:02:23 ( 19846 )    call  01072808195  728-100488
# 1812  2022-10-01 09:18:13 ( 19845 )    call  01049089797  728-108194
# 1813  2022-10-01 09:06:05 ( 19844 )    call  01029226264  728-103207
# 1814  2022-10-01 08:47:10 ( 19843 )      LN  01085213847  728-103378
# 1815  2022-10-01 08:44:30 ( 19842 )    call  01042282772  728-100842
#
#      System ID 사업부  제품별                                   병원명  \
# 0     07020303  DI   CT      Yonsei U. Gangnam Severance Hosp
# ...

# %%
raw = raw.dropna(subset = '응대/엔지니어')

# %%
raw['Date and Time'] = raw['접수시간'].str[:19]
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\3479168562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Date and Time'] = raw['접수시간'].str[:19]

# %%
raw['Date and Time'] = pd.to_datetime(raw['Date and Time'])
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\594018470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Date and Time'] = pd.to_datetime(raw['Date and Time'])

# %%
raw['Year'] = raw['Date and Time'].dt.year
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\1620092337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Year'] = raw['Date and Time'].dt.year

# %%
raw['Month'] = raw['Date and Time'].dt.month
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\1274002324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Month'] = raw['Date and Time'].dt.month

# %%
raw['Day'] = raw['Date and Time'].dt.day
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\180644516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Day'] = raw['Date and Time'].dt.day

# %%
raw['Time'] = raw['Date and Time'].dt.time
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\1490970487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Time'] = raw['Date and Time'].dt.time

# %%
raw
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 0     2023-01-01 07:56:39 ( 21472 )    call  01040262680  728-103708
# 1     2023-01-01 07:40:03 ( 21471 )    call  01062178238  728-100269
# 2     2023-01-01 07:20:00 ( 21470 )    call  01062178238  728-100269
# 3     2023-01-01 07:15:00 ( 21469 )    call  01032125690  728-100723
# 4     2023-01-01 07:13:23 ( 21468 )    call  01050471395  728-100440
# ...                             ...     ...          ...         ...
# 1811  2022-10-01 10:02:23 ( 19846 )    call  01072808195  728-100488
# 1812  2022-10-01 09:18:13 ( 19845 )    call  01049089797  728-108194
# 1813  2022-10-01 09:06:05 ( 19844 )    call  01029226264  728-103207
# 1814  2022-10-01 08:47:10 ( 19843 )      LN  01085213847  728-103378
# 1815  2022-10-01 08:44:30 ( 19842 )    call  01042282772  728-100842
#
#      System ID 사업부  제품별                                   병원명  \
# 0     07020303  DI   CT      Yonsei U. Gangnam Severance Hosp
# ...

# %%
raw['사업부'] = raw['사업부'].fillna('DX')
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\3127505133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['사업부'] = raw['사업부'].fillna('DX')

# %%
raw
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 0     2023-01-01 07:56:39 ( 21472 )    call  01040262680  728-103708
# 1     2023-01-01 07:40:03 ( 21471 )    call  01062178238  728-100269
# 2     2023-01-01 07:20:00 ( 21470 )    call  01062178238  728-100269
# 3     2023-01-01 07:15:00 ( 21469 )    call  01032125690  728-100723
# 4     2023-01-01 07:13:23 ( 21468 )    call  01050471395  728-100440
# ...                             ...     ...          ...         ...
# 1811  2022-10-01 10:02:23 ( 19846 )    call  01072808195  728-100488
# 1812  2022-10-01 09:18:13 ( 19845 )    call  01049089797  728-108194
# 1813  2022-10-01 09:06:05 ( 19844 )    call  01029226264  728-103207
# 1814  2022-10-01 08:47:10 ( 19843 )      LN  01085213847  728-103378
# 1815  2022-10-01 08:44:30 ( 19842 )    call  01042282772  728-100842
#
#      System ID 사업부  제품별                                   병원명  \
# 0     07020303  DI   CT      Yonsei U. Gangnam Severance Hosp
# ...

# %%
raw['Date and Time'].dt.hour
# Out:
# 0        7
# 1        7
# 2        7
# 3        7
# 4        7
#         ..
# 1811    10
# 1812     9
# 1813     9
# 1814     8
# 1815     8
# Name: Date and Time, Length: 1592, dtype: int64

# %%
raw['hour'] = raw['Date and Time'].dt.hour
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\2769611911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['hour'] = raw['Date and Time'].dt.hour

# %%
type(raw['hour'][0])
# Out:
# numpy.int64

# %%
raw['hour'] = raw['hour'].astype(str) + ' - ' + (raw['hour']+1).astype(str)
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\2294035017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['hour'] = raw['hour'].astype(str) + ' - ' + (raw['hour']+1).astype(str)

# %%
raw
# Out:
#                                접수시간 Call 유형         전화번호    FUNC LOC  \
# 0     2023-01-01 07:56:39 ( 21472 )    call  01040262680  728-103708
# 1     2023-01-01 07:40:03 ( 21471 )    call  01062178238  728-100269
# 2     2023-01-01 07:20:00 ( 21470 )    call  01062178238  728-100269
# 3     2023-01-01 07:15:00 ( 21469 )    call  01032125690  728-100723
# 4     2023-01-01 07:13:23 ( 21468 )    call  01050471395  728-100440
# ...                             ...     ...          ...         ...
# 1811  2022-10-01 10:02:23 ( 19846 )    call  01072808195  728-100488
# 1812  2022-10-01 09:18:13 ( 19845 )    call  01049089797  728-108194
# 1813  2022-10-01 09:06:05 ( 19844 )    call  01029226264  728-103207
# 1814  2022-10-01 08:47:10 ( 19843 )      LN  01085213847  728-103378
# 1815  2022-10-01 08:44:30 ( 19842 )    call  01042282772  728-100842
#
#      System ID 사업부  제품별                                   병원명  \
# 0     07020303  DI   CT      Yonsei U. Gangnam Severance Hosp
# ...

# %%
raw['Date'] = raw['Date and Time'].dt.date
# Out:
# C:\Users\z004n96k\AppData\Local\Temp\ipykernel_15968\3695660196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw['Date'] = raw['Date and Time'].dt.date

# %%
raw =raw[['접수시간','사업부','병원명','장비명',
         '응대/엔지니어','Dispatched/SVA','고장증상','조치사항','Call 유형','전화번호','FUNC LOC','System ID','제품별','장비명',
          '계약','STATUS','출발','일시작','일종료','Date and Time','Date','Year','Month','Day','Time','hour'
         ]]

# %%
raw.to_excel(writer, sheet_name='724')

# %%
writer.save()
